# %% [markdown]
# # Importing Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

import warnings
# %matplotlib inline

# %%
dataset = pd.read_csv("raw_ckd.csv")
mode_dataset = pd.read_csv("mode_ckd.csv")
mean_dataset = pd.read_csv("mean_ckd.csv")

# %%
cleanup = {"rbc":     {"normal": 1, "abnormal": 0},
           "pc": {"normal": 1, "abnormal": 0},
           "pcc": {"present": 1, "notpresent": 0},
           "ba": {"present": 1, "notpresent": 0},
           "htn": {"yes": 1, "no": 0},
           "dm": {"yes": 1, "no": 0},
           "cad": {"yes": 1, "no": 0},
           "appet": {"good": 1, "poor": 0},
           "pe": {"yes": 1, "no": 0},
           "ane": {"yes": 1, "no": 0},
           "class": {"ckd": 1, "notckd": 0}}

# %%
dataset.replace(cleanup, inplace = True)

# %%
cm = sns.light_palette("green", as_cmap=True)
dataset.head().style.background_gradient(cmap=cm).set_precision(2).highlight_null('red')
# Out:
# <style  type="text/css" >
#     #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col0 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col9 {
#             background-color:  #dbf9db;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col10 {
#             background-color:  #79c379;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col11 {
#             background-color:  #c7eec7;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col14 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col15 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col16 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col17 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col18 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col19 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col21 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row0_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col14 {
#             background-color:  #a2daa2;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col15 {
#             background-color:  #6abb6a;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col17 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  red;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col18 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col19 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col21 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row1_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b9482631row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_3aae3c02_2254_11eb_b05c_2016b

# %% [markdown]
# # KNN imputational process

# %%
from sklearn.impute import KNNImputer

# %%
features_list = []
for feature in dataset.columns:
    if feature != 'class':
        features_list.append(feature)
corrs = {}
for feature in features_list:
    corrs[feature] = dataset['class'].corr(dataset[feature])

# %%
def knnImputerDatasetGenerator(df, neighbors):
    
    imputer_uniform = KNNImputer(n_neighbors=neighbors, weights = 'uniform')
    dataset_uniform = imputer_uniform.fit_transform(df)
    
    return pd.DataFrame(dataset_uniform, columns = df.columns)

# %%
df_knn_imputed_uniform_3 = knnImputerDatasetGenerator(dataset, 3)
df_knn_imputed_uniform_5 = knnImputerDatasetGenerator(dataset, 5)
df_knn_imputed_uniform_7 = knnImputerDatasetGenerator(dataset, 7)
df_knn_imputed_uniform_9 = knnImputerDatasetGenerator(dataset, 9)
df_knn_imputed_uniform_11 = knnImputerDatasetGenerator(dataset, 11)

# %%
dataset.fillna(round(dataset.median(),2), inplace = True)

# %%
cm = sns.light_palette("green", as_cmap=True)
dataset.head().style.background_gradient(cmap=cm).set_precision(2).highlight_null('red')
# Out:
# <style  type="text/css" >
#     #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col0 {
#             background-color:  #3aa03a;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col9 {
#             background-color:  #dbf9db;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col10 {
#             background-color:  #79c379;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col11 {
#             background-color:  #c7eec7;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col12 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col13 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col14 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col15 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col16 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col17 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col18 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col19 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col21 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row0_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col9 {
#             background-color:  #dbf9db;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col12 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col13 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col14 {
#             background-color:  #a2daa2;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col15 {
#             background-color:  #6abb6a;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col17 {
#             background-color:  #46a746;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col18 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col19 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col21 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row1_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row2_col2 {
#             background-color:  #99d599;
#             color:  #000000;
#             : ;
#         }    #T_6991c5ca_2254_11eb_947d_2016b9482631row2

# %% [markdown]
# # KNN imputed MODELS for K = 3, 5, 7, 9 & 11

# %%
def models(x):
    
    if(x==0):
        classifier = LogisticRegression()
    elif(x==1):
        classifier = KNeighborsClassifier()
    elif(x==2):
        classifier = RandomForestClassifier(n_estimators = 500)
    elif(x==3):
        classifier = SVC(kernel='rbf',random_state=None)
    else:
        classifier = GaussianNB()
        
    res = {}
    
    #dfs: array of imputed df
    dfs = [df_knn_imputed_uniform_3,df_knn_imputed_uniform_5,
           df_knn_imputed_uniform_7,df_knn_imputed_uniform_9,
           df_knn_imputed_uniform_11]
    
    dfs_name = ["knn_imputed_3", "knn_imputed_5",
                "knn_imputed_7","knn_imputed_9",
                "knn_imputed_11"]
    
    for i, df in enumerate(dfs):
        X = df.iloc[:,:-1]
        y = df['class']
        X_train, X_test, y_train, y_test = train_test_split(X,y,shuffle = True, random_state = 2)
        
        ss = StandardScaler()
        X_train = ss.fit_transform(X_train)
        X_test = ss.transform(X_test)
        classifier.fit(X_train,y_train)
        
        test_pred = classifier.predict(X_test)
        train_pred = classifier.predict(X_train)
       
        # print(test_pred)
        train_acc = accuracy_score(y_train, train_pred)
        test_acc = accuracy_score(y_test, test_pred)
        
        tn, fp, fn, tp = confusion_matrix(y_test, test_pred).ravel()
        classification_report(y_test, test_pred)
        res[dfs_name[i]] = [train_acc, test_acc, tn, fp, fn, tp]
        
    return res

# %%
for i in range(5):
    result = models(i)
    res = pd.DataFrame.from_dict(data = result,orient='index', columns = ['train_acc', 'test_acc', 'true_neg', 'false_pos', 'false_neg', 'true_pos'])
    
    if(i==0):
        print("\033[1m",i+1,".PERFORMANCE INDICATORS for Logistic Regression \n")
    elif(i==1):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for KNN \n")
    elif(i==2):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Random Forest \n")
    elif(i==3):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for SVM \n")
    else:
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Naive Bayes \n")
        
    print(res,'\n')
# Out:
#  1 .PERFORMANCE INDICATORS for Logistic Regression
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# knn_imputed_3    0.993333      0.99        34          1          0        65
# knn_imputed_5    1.000000      0.99        34          1          0        65
# knn_imputed_7    1.000000      0.98        33          2          0        65
# knn_imputed_9    1.000000      0.98        33          2          0        65
# knn_imputed_11   1.000000      0.98        33          2          0        65
#
# 2 .PERFORMANCE INDICATORS for KNN
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# knn_imputed_3    0.973333      0.97        35          0          3        62
# knn_imputed_5    0.976667      0.97        35          0          3        62
# knn_imputed_7    0.983333      0.98        35          0          2        63
# knn_imputed_9    0.983333      0.97        35          0          3        62
# knn_imputed_11   0.983333      0.96        35          0          4        61
#
# 3 .PERFORMANCE INDICATORS for Random Forest
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# knn_imputed_3         1.0      0.99        34          1          0        65
# knn_imputed_5         1.0      0.98        33          2          0        65
# knn_imputed_7         1.0      0.98        33          2          0        65
# knn_imputed_9         1.0      0.98        33          2          0        65
# knn_imputed_11        1.0      0.98        33          2          0        65
#
# 4 .PERFORMANCE INDICATORS for SVM
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# knn_imputed_3    0.993333      0.99        34          1          0        65
# knn_imputed_5    0.996667      0.99        34          1          0        65
# knn_imputed_7    0.993333      0.99        34          1          0        65
# knn_imputed_9    0.996667      0.98        33          2          0        65
# knn_imputed_11   0.996667      0.98        33          2          0        65
#
# 5 .PERFORMANCE INDICATORS for Naive Bayes
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# knn_imputed_3    0.933333      0.94        34          1          5        60
# knn_imputed_5    0.936667      0.93        33          2          5        60
# knn_imputed_7    0.946667      0.94        33          2          4        61
# knn_imputed_9    0.946667      0.94        33          2          4        61
# knn_imputed_11   0.946667      0.93        33          2          5        60

# %% [markdown]
# # Mode Imputed MODELS

# %%
def fun1(x):
    
        if(x==0):
            classifier = LogisticRegression()
        elif(x==1):
            classifier = KNeighborsClassifier()
        elif(x==2):
            classifier = RandomForestClassifier(n_estimators = 500)
        elif(x==3):
            classifier = SVC(kernel='rbf',random_state=None)
        else:
            classifier = GaussianNB()
        
    
        res={}
        dfs_name2 = ["Log_Regression","K-NN","Random_Forest","SVM","Naive_Bayes"]
        X = mode_dataset.iloc[:,:-1]
        y = mode_dataset['class']
        X_train, X_test, y_train, y_test = train_test_split(X,y,shuffle = True, random_state = 2)

        ss = StandardScaler()
        X_train = ss.fit_transform(X_train)
        X_test = ss.transform(X_test)

#         classifier = LogisticRegression()
        classifier.fit(X_train, y_train)

        test_pred = classifier.predict(X_test)
        train_pred = classifier.predict(X_train)

#         print(test_pred)
        train_acc = accuracy_score(y_train, train_pred)
        test_acc = accuracy_score(y_test, test_pred)

        cm=metrics.confusion_matrix(y_test,test_pred)

        tn, fp, fn, tp = confusion_matrix(y_test, test_pred).ravel()
        classification_report(y_test, test_pred)
        res[dfs_name2[x]] = [train_acc, test_acc, tn, fp, fn, tp]
        
        return res

# %%
for i in range(5):
    result = fun1(i)
    res = pd.DataFrame.from_dict(data = result,orient='index', columns = ['train_acc', 'test_acc', 'true_neg', 'false_pos', 'false_neg', 'true_pos'])
    
    if(i==0):
        print("\033[1m",i+1,".PERFORMANCE INDICATORS for Logistic Regression \n")
    elif(i==1):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for KNN \n")
    elif(i==2):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Random Forest \n")
    elif(i==3):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for SVM \n")
    else:
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Naive Bayes \n")
    
    print(res,'\n\n')
# Out:
#  1 .PERFORMANCE INDICATORS for Logistic Regression
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Log_Regression        1.0       1.0        35          0          0        65
#
#
# 2 .PERFORMANCE INDICATORS for KNN
#
#       train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# K-NN       0.99      0.98        35          0          2        63
#
#
# 3 .PERFORMANCE INDICATORS for Random Forest
#
#                train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Random_Forest        1.0       1.0        35          0          0        65
#
#
# 4 .PERFORMANCE INDICATORS for SVM
#
#      train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# SVM        1.0       1.0        35          0          0        65
#
#
# 5 .PERFORMANCE INDICATORS for Naive Bayes
#
#              train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Naive_Bayes       0.95      0.95        33          2          3        62

# %% [markdown]
# # Mean Imputed MODELS

# %%
def fun2(x):
    
        if(x==0):
            classifier = LogisticRegression()
        elif(x==1):
            classifier = KNeighborsClassifier()
        elif(x==2):
            classifier = RandomForestClassifier(n_estimators = 500)
        elif(x==3):
            classifier = SVC(kernel='rbf',random_state=None)
        else:
            classifier = GaussianNB()
        
    
        res={}
        dfs_name2 = ["Log_Regression","K-NN","Random_Forest","SVM","Naive_Bayes"]
        X = mean_dataset.iloc[:,:-1]
        y = mean_dataset['class']
        X_train, X_test, y_train, y_test = train_test_split(X,y,shuffle = True, random_state = 2)

        ss = StandardScaler()
        X_train = ss.fit_transform(X_train)
        X_test = ss.transform(X_test)

#         classifier = LogisticRegression()
        classifier.fit(X_train, y_train)

        test_pred = classifier.predict(X_test)
        train_pred = classifier.predict(X_train)

#         print(test_pred)
        train_acc = accuracy_score(y_train, train_pred)
        test_acc = accuracy_score(y_test, test_pred)

        cm=metrics.confusion_matrix(y_test,test_pred)

        tn, fp, fn, tp = confusion_matrix(y_test, test_pred).ravel()
        classification_report(y_test, test_pred)
        res[dfs_name2[x]] = [train_acc, test_acc, tn, fp, fn, tp]
        
        return res

# %%
for i in range(5):
    result = fun2(i)
    res = pd.DataFrame.from_dict(data = result,orient='index', columns = ['train_acc', 'test_acc', 'true_neg', 'false_pos', 'false_neg', 'true_pos'])
    
    if(i==0):
        print("\033[1m",i+1,".PERFORMANCE INDICATORS for Logistic Regression \n")
    elif(i==1):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for KNN \n")
    elif(i==2):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Random Forest \n")
    elif(i==3):
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for SVM \n")
    else:
        print(i+1,"\033[1m"+".PERFORMANCE INDICATORS for Naive Bayes \n")
    
    print(res,'\n\n')
# Out:
#  1 .PERFORMANCE INDICATORS for Logistic Regression
#
#                 train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Log_Regression        1.0       1.0        35          0          0        65
#
#
# 2 .PERFORMANCE INDICATORS for KNN
#
#       train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# K-NN       0.99      0.98        35          0          2        63
#
#
# 3 .PERFORMANCE INDICATORS for Random Forest
#
#                train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Random_Forest        1.0       1.0        35          0          0        65
#
#
# 4 .PERFORMANCE INDICATORS for SVM
#
#      train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# SVM        1.0       1.0        35          0          0        65
#
#
# 5 .PERFORMANCE INDICATORS for Naive Bayes
#
#              train_acc  test_acc  true_neg  false_pos  false_neg  true_pos
# Naive_Bayes       0.95      0.95        33          2          3        62
