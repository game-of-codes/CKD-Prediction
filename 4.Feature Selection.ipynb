# %% [markdown]
# # Feature Selection

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import *
import zipfile
from zipfile import ZipFile

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df_knn_imputed_uniform_3 = pd.read_csv('df_knn_imputed_uniform_3.csv')
df_knn_imputed_uniform_5 = pd.read_csv('df_knn_imputed_uniform_5.csv')
df_knn_imputed_uniform_7 = pd.read_csv('df_knn_imputed_uniform_7.csv')
df_knn_imputed_uniform_9 = pd.read_csv('df_knn_imputed_uniform_9.csv')
df_knn_imputed_uniform_11 = pd.read_csv('df_knn_imputed_uniform_11.csv')
df_mean_imputed = pd.read_csv('df_mean_imputed.csv')

# %% [markdown]
# Removing unwanted Column from all datasets

# %%
df_knn_imputed_uniform_3.drop(['Unnamed: 0'],axis=1,inplace=True)
df_knn_imputed_uniform_5.drop(['Unnamed: 0'],axis=1,inplace=True)
df_knn_imputed_uniform_7.drop(['Unnamed: 0'],axis=1,inplace=True)
df_knn_imputed_uniform_9.drop(['Unnamed: 0'],axis=1,inplace=True)
df_knn_imputed_uniform_11.drop(['Unnamed: 0'],axis=1,inplace=True)
df_mean_imputed.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df_knn_imputed_uniform_3.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'class'],
#       dtype='object')

# %%
def test_split(x):
    if(x==0):
        dataset = df_knn_imputed_uniform_3
    elif(x==1):
        dataset = df_knn_imputed_uniform_5
    elif(x==2):
        dataset = df_knn_imputed_uniform_7
    elif(x==3):
        dataset = df_knn_imputed_uniform_9
    elif(x==4):
        dataset = df_knn_imputed_uniform_11
    else:
        dataset = df_mean_imputed
        
    df_train,df_test = train_test_split(dataset,train_size=0.7,random_state=42)
    x_train=df_train.iloc[:,:24]
    y_train=df_train['class']
    scaler.fit(x_train)
    x_train_sc=scaler.transform(x_train)
    x_test=df_test.iloc[:,:24]
    y_test=df_test['class']
    scaler.fit(x_test)
    x_test_sc=scaler.transform(x_test)

# %%
for i in range(6):
    test_split(i)
    
    rfc = RandomForestClassifier(n_estimators=50,random_state=0)
    ## fitiing the model
    rfc.fit(x_train_sc, y_train)

    feature_list = list(x_train.columns)
    importances = list(rfc.feature_importances_)
    feature_importances = [(x_train, round(importance, 2)) for x_train, importance in zip(feature_list, importances)]
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
    
    print('\n\n')
# Out:
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0
#
#
#
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0
#
#
#
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0
#
#
#
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0
#
#
#
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0
#
#
#
# Variable: sg                   Importance: 0.2
# Variable: hemo                 Importance: 0.15
# Variable: al                   Importance: 0.14
# Variable: sc                   Importance: 0.11
# Variable: pcv                  Importance: 0.09
# Variable: rbc                  Importance: 0.07
# Variable: rbcc                 Importance: 0.05
# Variable: bgr                  Importance: 0.03
# Variable: bp                   Importance: 0.02
# Variable: bu                   Importance: 0.02
# Variable: htn                  Importance: 0.02
# Variable: dm                   Importance: 0.02
# Variable: appet                Importance: 0.02
# Variable: pe                   Importance: 0.02
# Variable: age                  Importance: 0.01
# Variable: su                   Importance: 0.01
# Variable: pc                   Importance: 0.01
# Variable: sod                  Importance: 0.01
# Variable: pot                  Importance: 0.01
# Variable: wbcc                 Importance: 0.01
# Variable: pcc                  Importance: 0.0
# Variable: ba                   Importance: 0.0
# Variable: cad                  Importance: 0.0
# Variable: ane                  Importance: 0.0

# %% [markdown]
# We Can see the most useful column from all the KNN-Imputed and mean Imputed datasets are same.

# %% [markdown]
# Now we should drop all the column whose Importance is 0.01 or less

# %%
def drop_column(x):
    if(x==0):
        dataset = df_knn_imputed_uniform_3
    elif(x==1):
        dataset = df_knn_imputed_uniform_5
    elif(x==2):
        dataset = df_knn_imputed_uniform_7
    elif(x==3):
        dataset = df_knn_imputed_uniform_9
    elif(x==4):
        dataset = df_knn_imputed_uniform_11
    else:
        dataset = df_mean_imputed
    
    drop_col_list=['age','su','pc','sod','pot' , 'wbcc' , 'pcc' ,
               'ba' , 'cad' , 'ane']
    dataset.drop(drop_col_list,axis=1,inplace=True)

# %%
for i in range(6):
    drop_column(i)
